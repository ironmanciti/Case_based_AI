# %% [markdown]
# # 070. 컴퓨터 비전(Vision)을 위한 전이학습(Transfer Learning)
# =======================================================
#
# - 실제로 충분한 크기의 데이터셋을 갖추기는 상대적으로 드물기 때문에,(무작위 초기화를 통해) 맨 처음부터 합성곱 신경망(Convolutional Network) 전체를 작성하는 경우는 매우 적다.
# - 대신, 매우 큰 데이터셋(예. 100가지 분류에 대해 120만개의 이미지가 포함된 ImageNet)에서 합성곱 신경망(ConvNet)을 미리 학습한 후, 이 합성곱 신경망을 관심있는 작업을 위한 초기 설정 또는 고정된 특징 추출기(fixed feature extractor)로 사용
#
# ### 전이학습의 2 가지 시나리오:
#
# -  **합성곱 신경망의 미세조정(finetuning)**: 신경망을 ImageNet 등으로 미리 학습한 신경망으로 초기화하고 parameter 미세 조정
# -  **고정된 특징 추출기로써의 합성곱 신경망**: 마지막 완전 연결층을 제외한 모든 신경망의 가중치를 고정. 마지막의 완전 연결층은 새로운 무작위의 가중치를 갖는 계층으로 대체되어 이 계층만 학습.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# 데이터 불러오기
# ---------------
#
# - **개미** 와 **벌** 을 분류하는 모델을 학습
#     - 대략 120장 정도의 훈련 이미지와, 75장의 검증용 이미지를 이용
#     - 전이학습을 통해 소량의 데이터로도 일반화 가능
#     - ImageNet의 일부 data 이용
#
# .. Note ::
#    데이터를 `여기` <https://download.pytorch.org/tutorial/hymenoptera_data.zip>
#    에서 다운로드 받아 현재 디렉토리에 압축을 푼다

# %%
# 데이터 증가(augmentation) 및 normalization 적용
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %% [markdown]
# # ImageFolder 라이브러리
#
# - 계층적인 폴더 구조를 가지고 있는 데이터셋을 불러올 때 사용할 수 있다. 각 이미지들이 자신의 레이블(Label) 이름으로 된 폴더 안에 들어가 있는 구조라면, ImageFolder 라이브러리를 이용하여 이를 바로 불러와 객체로 만들면 된다.

# %%
data_dir = 'hymenoptera_data'
train_dir = os.path.join(data_dir, 'train')
val_dir  = os.path.join(data_dir, 'val')

print(os.listdir(data_dir))
print(os.listdir(train_dir))
print(os.listdir(val_dir))
# Out:
# ['train', 'val']
# ['ants', 'bees']
# ['ants', 'bees']

# %% [markdown]
# ### datasets.ImageFolder(folder, transform) data loader 생성

# %%
train_data = datasets.ImageFolder(os.path.join(data_dir, 'train'), 
                                          data_transforms['train']) 
val_data = datasets.ImageFolder(os.path.join(data_dir, 'val'), 
                                          data_transforms['val'])

train_loader = torch.utils.data.DataLoader(train_data, 
                                batch_size=4, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, 
                                batch_size=4, shuffle=True)

# %%
class_names = train_data.classes
class_names
# Out:
# ['ants', 'bees']

# %%
print(len(train_data), len(val_data))
print(class_names)
# Out:
# 244 153
# ['ants', 'bees']

# %% [markdown]
# ### 일부 이미지 시각화하기

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose(1, 2, 0)
    mean = np.array([0.485, 0.456, 0.406])
    std  = np.array([0.229, 0.224, 0.225])
    inp  = inp * std + mean
    inp  = np.clip(inp, 0, 1)
    plt.title(title)
    plt.imshow(inp)

# %%
inputs, classes = next(iter(train_loader))
out = torchvision.utils.make_grid(inputs)
imshow(out, [class_names[x] for x in classes])

# %% [markdown]
# Model Train
# --------------
#
# -  학습율(learning rate) 관리(scheduling)
# -  최적의 모델 구하기
#
# - 아래에서 ``scheduler`` 매개변수는 ``torch.optim.lr_scheduler`` 의 LR 스케쥴러 객체(Object)

# %% [markdown]
# ## 1. 합성곱 신경망 미세조정(finetuning)
#
# - 미리 학습한 모델을 불러온 후 마지막의 완전 연결층을 초기화
#
# ### torch 제공 pre-trained models
# ```
#     import torchvision.models as models
#
#     resnet18 = models.resnet18()
#     alexnet = models.alexnet()
#     vgg16 = models.vgg16()
#     squeezenet = models.squeezenet1_0()
#     densenet = models.densenet161()
#     inception = models.inception_v3()
#     googlenet = models.googlenet()
#     shufflenet = models.shufflenet_v2_x1_0()
#     mobilenet = models.mobilenet_v2()
#     resnext50_32x4d = models.resnext50_32x4d()
#     wide_resnet50_2 = models.wide_resnet50_2()
#     mnasnet = models.mnasnet1_0()
# ```

# %%
model_ft = torchvision.models.resnet18(pretrained=True)

num_features = model_ft.fc.in_features
num_features
# Out:
# 512

# %%
# 여기서 fc layer 출력의 크기를 1000 에서 2로 변경
model_ft.fc = nn.Linear(num_features, 2)
model_ft.fc
# Out:
# Linear(in_features=512, out_features=2, bias=True)

# %%
model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# 7 에폭마다 0.1 비율로 learning rate decay
scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    st = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs-1))
        print('-' * 10)

        model.train()  # 모델을 학습 모드로 설정
        cost = 0
        corrects = 0

        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            optimizer.zero_grad()

            z = model(x)
            _, preds = torch.max(z, 1)
        
            loss = criterion(z, y)
            loss.backward()
            optimizer.step()

            cost += loss.item() * x.size(0)
            corrects += torch.sum(preds == y.data)

        train_acc = corrects / len(train_data)  
        train_loss = cost / len(train_data)
        
        scheduler.step()

        model.eval()  # 모델을 학습 모드로 설정
        cost = 0
        corrects = 0
        
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)

                z = model(x)
                _, preds = torch.max(z, 1)

                loss = criterion(z, y)

                cost += loss.item() * x.size(0)
                corrects += torch.sum(preds == y.data)

        val_acc  = corrects / len(val_data)    
        val_loss = cost / len(val_data)

        print(f'eEpoch {epoch+1}/{num_epochs}==> train loss: {train_loss:.4f} ' + 
              f'val loss: {val_loss:.4f} ' + f'train acc: {train_acc:.2f} ' + 
              f'val acc: {val_acc:.2f}')

        # 모델을 깊은 복사(deep copy)함
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - st
    print('Training complete in {:.0f}m {:.0f}s'.format(
            time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # 가장 나은 모델 가중치를 불러옴
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# eEpoch 1/25==> train loss: 0.6386 val loss: 0.2922 train acc: 0.71 val acc: 0.88
# Epoch 1/24
# ----------
# eEpoch 2/25==> train loss: 0.5376 val loss: 0.2962 train acc: 0.76 val acc: 0.90
# Epoch 2/24
# ----------
# eEpoch 3/25==> train loss: 0.5992 val loss: 0.3193 train acc: 0.76 val acc: 0.88
# Epoch 3/24
# ----------
# eEpoch 4/25==> train loss: 0.5579 val loss: 0.3290 train acc: 0.80 val acc: 0.90
# Epoch 4/24
# ----------
# eEpoch 5/25==> train loss: 0.6366 val loss: 0.4843 train acc: 0.77 val acc: 0.84
# Epoch 5/24
# ----------
# eEpoch 6/25==> train loss: 0.5862 val loss: 0.3326 train acc: 0.76 val acc: 0.86
# Epoch 6/24
# ----------
# eEpoch 7/25==> train loss: 0.3599 val loss: 0.3217 train acc: 0.84 val acc: 0.90
# Epoch 7/24
# ----------
# eEpoch 8/25==> train loss: 0.3347 val loss: 0.2648 train acc: 0.84 val acc: 0.91
# Epoch 8/24
# ----------
# eEpoch 9/25==> train loss: 0.2173 val loss: 0.2543 train acc: 0.92 val acc: 0.92
# Epoch 9/24
# ----------
# eEpoch 10/25==> train loss: 0.3139 val loss: 0.2657 train acc: 0.85 val acc: 0.92
# Epoch 10/24
# ----------
# eEpoch 11/25==> train loss: 0.2925 val loss: 0.2368 train acc: 0.89 val acc: 0.93
# Epoch 11/24
# ----------
# eEpoch 12/25==> train loss: 0.2890 val loss: 0.2288 train acc: 0.86 val acc: 0.92
# Epoch 12/24
# ----------
# eEpoch 13/25==> train loss: 0.2060 val loss: 0.2373 train acc: 0.93 val acc: 0.92
# Epoch 13/24
# ----------
# eEpoch 14/25==> train loss: 0.3411 val loss: 0.2379 train acc: 0.86 val acc: 0.92
# Epoch 14/24
# ----------
# eEpoch 15/25==> train loss: 0.2780 val loss: 0.2257 train acc: 0.87 val acc: 0.93
# Epoch 15/24
# ----------
# eEpoch 16/25==> train loss: 0.3201 val loss: 0.2531 train acc: 0.86 val acc: 0.90
# Epoch 16/24
# ----------
# eEpoch 17/25==> train loss: 0.2106 val loss: 0.2278 train acc: 0.93 val acc: 0.92
# Epoch 17/24
# ----------
# eEpoch 18/25==> train loss: 0.2579 val loss: 0.2292 train acc: 0.89 val acc: 0.93
# Epoch 18/24
# ----------
# eEpoch 19/25==> train loss: 0.2757 val loss: 0.2568 train acc: 0.88 val acc: 0.91
# Epoch 19/24
# ----------
# eEpoch 20/25==> train loss: 0.2973 val loss: 0.2368 train acc: 0.89 val acc: 0.92
# Epoch 20/24
# ----------
# eEpoch 21/25==> train loss: 0.2854 val loss: 0.2265 train acc: 0.86 val acc: 0.93
# Epoch 21/24
# ----------
# eEpoch 22/25==> train loss: 0.2274 val loss: 0.2230 train acc: 0.91 val acc: 0.93
# Epoch 22/24
# ----------
# eEpoch 23/25==> train loss: 0.2426 val loss: 0.2750 train acc: 0.88 val acc: 0.92
# Epoch 23/24
# ----------
# eEpoch 24/25==> train loss: 0.2520 val loss: 0.2253 train acc: 0.90 val acc: 0.93
# Epoch 24/24
# ----------
# eEpoch 25/25==> train loss: 0.2402 val loss: 0.2411 train acc: 0.89 val acc: 0.93
# Training complete in 3m 58s
# Best val Acc: 0.934641

# %%
predictions = []
labels = []

with torch.no_grad():
    for x, y in val_loader:
        x, y = x.to(device), y.to(device)

        z = model_ft(x)
        _, preds = torch.max(z, 1)
        
        predictions.extend(preds.cpu().numpy())
        labels.extend(y.cpu().numpy())
        
    correct_indices = np.nonzero(np.array(predictions) == np.array(labels))[0]
    incorrect_indices = np.nonzero(np.array(predictions) != np.array(labels))[0]

print("accuracy = %.2f %%" % (len(correct_indices) / len(predictions) * 100))
# Out:
# accuracy = 93.46 %

# %%
inputs = []
for i, idx in enumerate(correct_indices[:9]):
    inputs.append(val_data[idx][0])
out = torchvision.utils.make_grid(inputs, nrow=9)
plt.figure(figsize=(12, 4))
imshow(out, 'correct')

inputs = []
for i, idx in enumerate(incorrect_indices[:9]):
    inputs.append(val_data[idx][0])
out = torchvision.utils.make_grid(inputs, nrow=9)
plt.figure(figsize=(12, 4))
imshow(out, 'incorrect')

# %% [markdown]
# 고정된 특징 추출기로써의 합성곱 신경망
# ---------------------------------------
#
# - 마지막 계층을 제외한 신경망의 모든 부분을 고정
# - ``requires_grad == False`` 로 설정하여 매개변수를 고정하여 ``backward()`` 중에 경사도가 계산되지 않도록 함

# %%
model_conv = torchvision.models.resnet18(pretrained=True)

for param in model_conv.parameters():
    param.requires_grad = False

# %%
# 새로 생성된 모듈의 매개변수는 기본값이 requires_grad=True 임
num_features = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_features, 2)

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %% [markdown]
# ## Train & Evaluation

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# eEpoch 1/25==> train loss: 0.6360 val loss: 0.2271 train acc: 0.66 val acc: 0.92
# Epoch 1/24
# ----------
# eEpoch 2/25==> train loss: 0.4818 val loss: 0.2887 train acc: 0.77 val acc: 0.86
# Epoch 2/24
# ----------
# eEpoch 3/25==> train loss: 0.6409 val loss: 0.2319 train acc: 0.73 val acc: 0.93
# Epoch 3/24
# ----------
# eEpoch 4/25==> train loss: 0.5124 val loss: 0.1989 train acc: 0.82 val acc: 0.94
# Epoch 4/24
# ----------
# eEpoch 5/25==> train loss: 0.4501 val loss: 0.2334 train acc: 0.83 val acc: 0.94
# Epoch 5/24
# ----------
# eEpoch 6/25==> train loss: 0.5452 val loss: 0.3545 train acc: 0.78 val acc: 0.85
# Epoch 6/24
# ----------
# eEpoch 7/25==> train loss: 0.5520 val loss: 0.2926 train acc: 0.80 val acc: 0.91
# Epoch 7/24
# ----------
# eEpoch 8/25==> train loss: 0.4638 val loss: 0.2179 train acc: 0.81 val acc: 0.95
# Epoch 8/24
# ----------
# eEpoch 9/25==> train loss: 0.3083 val loss: 0.2786 train acc: 0.85 val acc: 0.91
# Epoch 9/24
# ----------
# eEpoch 10/25==> train loss: 0.3154 val loss: 0.2024 train acc: 0.86 val acc: 0.95
# Epoch 10/24
# ----------
# eEpoch 11/25==> train loss: 0.3795 val loss: 0.2319 train acc: 0.82 val acc: 0.93
# Epoch 11/24
# ----------
# eEpoch 12/25==> train loss: 0.4079 val loss: 0.2066 train acc: 0.84 val acc: 0.94
# Epoch 12/24
# ----------
# eEpoch 13/25==> train loss: 0.3296 val loss: 0.2302 train acc: 0.86 val acc: 0.94
# Epoch 13/24
# ----------
# eEpoch 14/25==> train loss: 0.3610 val loss: 0.2008 train acc: 0.85 val acc: 0.95
# Epoch 14/24
# ----------
# eEpoch 15/25==> train loss: 0.4163 val loss: 0.2026 train acc: 0.81 val acc: 0.95
# Epoch 15/24
# ----------
# eEpoch 16/25==> train loss: 0.3170 val loss: 0.2293 train acc: 0.86 val acc: 0.93
# Epoch 16/24
# ----------
# eEpoch 17/25==> train loss: 0.4127 val loss: 0.2139 train acc: 0.83 val acc: 0.94
# Epoch 17/24
# ----------
# eEpoch 18/25==> train loss: 0.3387 val loss: 0.2150 train acc: 0.86 val acc: 0.95
# Epoch 18/24
# ----------
# eEpoch 19/25==> train loss: 0.3595 val loss: 0.2085 train acc: 0.85 val acc: 0.95
# Epoch 19/24
# ----------
# eEpoch 20/25==> train loss: 0.3814 val loss: 0.2231 train acc: 0.84 val acc: 0.95
# Epoch 20/24
# ----------
# eEpoch 21/25==> train loss: 0.4177 val loss: 0.2115 train acc: 0.80 val acc: 0.95
# Epoch 21/24
# ----------
# eEpoch 22/25==> train loss: 0.3542 val loss: 0.2090 train acc: 0.84 val acc: 0.95
# Epoch 22/24
# ----------
# eEpoch 23/25==> train loss: 0.3591 val loss: 0.1995 train acc: 0.83 val acc: 0.94
# Epoch 23/24
# ----------
# eEpoch 24/25==> train loss: 0.2668 val loss: 0.2036 train acc: 0.90 val acc: 0.95
# Epoch 24/24
# ----------
# eEpoch 25/25==> train loss: 0.3232 val loss: 0.2056 train acc: 0.85 val acc: 0.95
# Training complete in 2m 35s
# Best val Acc: 0.954248

# %%
predictions = []
labels = []

with torch.no_grad():
    for x, y in val_loader:
        x, y = x.to(device), y.to(device)

        z = model_ft(x)
        _, preds = torch.max(z, 1)
        
        predictions.extend(preds.cpu().numpy())
        labels.extend(y.cpu().numpy())
        
    correct_indices = np.nonzero(np.array(predictions) == np.array(labels))[0]
    incorrect_indices = np.nonzero(np.array(predictions) != np.array(labels))[0]

print("accuracy = %.2f %%" % (len(correct_indices) / len(predictions) * 100))
# Out:
# accuracy = 93.46 %

# %%
inputs = []
for i, idx in enumerate(correct_indices[:9]):
    inputs.append(val_data[idx][0])
out = torchvision.utils.make_grid(inputs, nrow=9)
plt.figure(figsize=(24, 8))
imshow(out, 'correct')

inputs = []
for i, idx in enumerate(incorrect_indices[:9]):
    inputs.append(val_data[idx][0])
out = torchvision.utils.make_grid(inputs, nrow=9)
plt.figure(figsize=(24, 8))
imshow(out, 'incorrect')
